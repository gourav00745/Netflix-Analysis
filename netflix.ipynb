# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import pyplot
# %matplotlib inline

# %%
df=pd.read_csv("C:/Users/Gaurav/Desktop/Projects/OTT/netf.csv")

# %%
df1=pd.read_csv("C:/Users/Gaurav/Desktop/Projects/OTT/netf.csv")

# %%
df1
# Out:
#                                            Title  \
# 0                               Lets Fight Ghost
# 1                            HOW TO BUILD A GIRL
# 2                                     Centigrade
# 3                                          ANNE+
# 4                                          Moxie
# ...                                          ...
# 15475                     K-POP Extreme Survival
# 15476            DreamWorks Shreks Swamp Stories
# 15477  DreamWorks Happy Holidays from Madagascar
# 15478                DreamWorks Holiday Classics
# 15479   DreamWorks Kung Fu Panda Awesome Secrets
#
#                                         Genre  \
# 0      Crime, Drama, Fantasy, Horror, Romance
# 1                                      Comedy
# 2                             Drama, Thriller
# 3                                       Drama
# 4                     Animation, Short, Drama
# ...                                       ...
# ...

# %%
df.head()
# Out:
#                  Title                                   Genre  \
# 0     Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
# 1  HOW TO BUILD A GIRL                                  Comedy
# 2           Centigrade                         Drama, Thriller
# 3                ANNE+                                   Drama
# 4                Moxie                 Animation, Short, Drama
#
#                                                 Tags         Languages  \
# 0  Comedy Programmes,Romantic TV Comedies,Horror ...  Swedish, Spanish
# 1       Dramas,Comedies,Films Based on Books,British           English
# 2                                          Thrillers           English
# 3        TV Dramas,Romantic TV Dramas,Dutch TV Shows           Turkish
# 4  Social Issue Dramas,Teen Movies,Dramas,Comedie...           English
#
#   Series or Movie  Hidden Gem Score  \
# 0          Series               4.3
# 1           Movie               7.0
# 2           Movie               6.4
# ...

# %%
df.sample(5)
# Out:
#                         Title                                         Genre  \
# 13596  Star Trek: Generations  Action, Adventure, Mystery, Sci-Fi, Thriller
# 4073              Wok of Love                               Comedy, Romance
# 4838                  Inmates                                        Comedy
# 2406              Stuck Apart                                 Comedy, Drama
# 3958               Charleston                                 Comedy, Drama
#
#                                                     Tags         Languages  \
# 13596  Alien Sci-Fi,Sci-Fi & Fantasy,Action Sci-Fi & ...  English, Klingon
# 4073    TV Comedies,Romantic TV Comedies,Korean TV Shows            Korean
# 4838   Hindi-Language TV Shows,TV Comedies,Indian TV ...               NaN
# 2406        Dark Comedies,Dramas,Comedies,Turkish Movies           Turkish
# 3958                       Comedies,Dramas,Dark Comedies          Romanian
#
#       Series or Movie  Hidden Gem Score  \
# ...

# %%
df.isnull().sum()
# Out:
# Title                        0
# Genre                     1710
# Tags                        67
# Languages                 1935
# Series or Movie              0
# Hidden Gem Score          2101
# Country Availability        19
# Runtime                      1
# Director                  4708
# Writer                    4330
# Actors                    1925
# View Rating               7024
# IMDb Score                2099
# Rotten Tomatoes Score     9098
# Metacritic Score         11144
# Awards Received           9405
# Awards Nominated For      7819
# Boxoffice                11473
# Release Date              2107
# Netflix Release Date         0
# Production House         10331
# Netflix Link                 0
# IMDb Link                 2303
# Summary                      9
# IMDb Votes                2101
# Image                        0
# Poster                    3638
# TMDb Trailer              8286
# Trailer Site              8286
# dtype: int64

# %%
df.dtypes
# Out:
# Title                     object
# Genre                     object
# Tags                      object
# Languages                 object
# Series or Movie           object
# Hidden Gem Score         float64
# Country Availability      object
# Runtime                   object
# Director                  object
# Writer                    object
# Actors                    object
# View Rating               object
# IMDb Score               float64
# Rotten Tomatoes Score    float64
# Metacritic Score         float64
# Awards Received          float64
# Awards Nominated For     float64
# Boxoffice                 object
# Release Date              object
# Netflix Release Date      object
# Production House          object
# Netflix Link              object
# IMDb Link                 object
# Summary                   object
# IMDb Votes               float64
# Image                     object
# Poster                    object
# TMDb Trailer              object
# ...

# %%
df['Genre']=df['Genre'].fillna(df['Genre'].mode()[0])

# %%
df['Genre'].unique()
# Out:
# array(['Crime, Drama, Fantasy, Horror, Romance', 'Comedy',
#        'Drama, Thriller', ..., 'Action, Animation, Comedy, Romance',
#        'Animation, Action, Adventure, Fantasy, Sport, Thriller',
#        'Adventure, Drama, Fantasy, Romance, Thriller'], dtype=object)

# %%
for i in range(len(df['Genre'])):
        df['Genre'][i]+=","
# Out:
# C:\Users\Gaurav\AppData\Local\Temp\ipykernel_8712\1156661937.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Genre'][i]+=","

# %%
a=df['Genre'].str.split(",")

# %%
for i in range(len(df['Genre'])):
    df['Genre'][i]=a[i][0]
# Out:
# C:\Users\Gaurav\AppData\Local\Temp\ipykernel_8712\3066317233.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Genre'][i]=a[i][0]

# %%
df
# Out:
#                                            Title      Genre  \
# 0                               Lets Fight Ghost      Crime
# 1                            HOW TO BUILD A GIRL     Comedy
# 2                                     Centigrade      Drama
# 3                                          ANNE+      Drama
# 4                                          Moxie  Animation
# ...                                          ...        ...
# 15475                     K-POP Extreme Survival     Comedy
# 15476            DreamWorks Shreks Swamp Stories     Comedy
# 15477  DreamWorks Happy Holidays from Madagascar  Animation
# 15478                DreamWorks Holiday Classics  Animation
# 15479   DreamWorks Kung Fu Panda Awesome Secrets  Animation
#
#                                                     Tags         Languages  \
# 0      Comedy Programmes,Romantic TV Comedies,Horror ...  Swedish, Spanish
# 1           Dramas,Comedies,Films Based on Books,British           English
# ...

# %%
df=df.drop(columns=['Tags','Country Availability','Director','Writer','Actors','Hidden Gem Score','Metacritic Score','Production House','Netflix Link','IMDb Link','Summary','IMDb Votes','TMDb Trailer','Trailer Site'])

# %%
df.sample(6)
# Out:
#                     Title        Genre Languages Series or Movie  \
# 12927            Balkwang       Comedy       NaN          Series
# 6090         Eighth Grade       Comedy   English           Movie
# 12772  Girls Incarcerated  Documentary   English          Series
# 12134       Ninja Kids!!!       Action  Japanese           Movie
# 2815   The Devil Punisher      Fantasy  Mandarin          Series
# 15215            Twilight        Drama   English           Movie
#
#             Runtime View Rating  IMDb Score  Rotten Tomatoes Score  \
# 12927  < 30 minutes         NaN         NaN                    NaN
# 6090       1-2 hour           R         7.4                   99.0
# 12772  < 30 minutes       TV-MA         7.3                    NaN
# 12134      1-2 hour         NaN         5.8                    NaN
# 2815   < 30 minutes         NaN         6.1                    NaN
# 15215       > 2 hrs       PG-13         5.2                   49.0
#
# ...

# %%
df['Languages']=df['Languages'].fillna(df['Languages'].mode()[0])
for i in range(len(df['Languages'])):
        df['Languages'][i]+=","
a=df['Languages'].str.split(",")
for i in range(len(df['Languages'])):
    df['Languages'][i]=a[i][0]
# Out:
# C:\Users\Gaurav\AppData\Local\Temp\ipykernel_8712\3961156122.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Languages'][i]+=","
# C:\Users\Gaurav\AppData\Local\Temp\ipykernel_8712\3961156122.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Languages'][i]=a[i][0]

# %%
df
# Out:
#                                            Title      Genre Languages  \
# 0                               Lets Fight Ghost      Crime   Swedish
# 1                            HOW TO BUILD A GIRL     Comedy   English
# 2                                     Centigrade      Drama   English
# 3                                          ANNE+      Drama   Turkish
# 4                                          Moxie  Animation   English
# ...                                          ...        ...       ...
# 15475                     K-POP Extreme Survival     Comedy   English
# 15476            DreamWorks Shreks Swamp Stories     Comedy   English
# 15477  DreamWorks Happy Holidays from Madagascar  Animation   English
# 15478                DreamWorks Holiday Classics  Animation   English
# 15479   DreamWorks Kung Fu Panda Awesome Secrets  Animation   English
#
#       Series or Movie       Runtime View Rating  IMDb Score  \
# 0              Series  < 30 minutes           R         7.9
# ...

# %%
df['Runtime']=df['Runtime'].fillna(df['Runtime'].mode()[0])
df['View Rating']=df['View Rating'].fillna(df['View Rating'].mode()[0])
df['Awards Received']=df['Awards Received'].fillna(0)
df['Awards Nominated For']=df['Awards Nominated For'].fillna(0)
df['Boxoffice']=df['Boxoffice'].str.replace('$','')
# Out:
# C:\Users\Gaurav\AppData\Local\Temp\ipykernel_8712\1395607753.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Boxoffice']=df['Boxoffice'].str.replace('$','')

# %%
df
# Out:
#                                            Title      Genre Languages  \
# 0                               Lets Fight Ghost      Crime   Swedish
# 1                            HOW TO BUILD A GIRL     Comedy   English
# 2                                     Centigrade      Drama   English
# 3                                          ANNE+      Drama   Turkish
# 4                                          Moxie  Animation   English
# ...                                          ...        ...       ...
# 15475                     K-POP Extreme Survival     Comedy   English
# 15476            DreamWorks Shreks Swamp Stories     Comedy   English
# 15477  DreamWorks Happy Holidays from Madagascar  Animation   English
# 15478                DreamWorks Holiday Classics  Animation   English
# 15479   DreamWorks Kung Fu Panda Awesome Secrets  Animation   English
#
#       Series or Movie       Runtime View Rating  IMDb Score  \
# 0              Series  < 30 minutes           R         7.9
# ...

# %%
df.dtypes
# Out:
# Title                     object
# Genre                     object
# Languages                 object
# Series or Movie           object
# Runtime                   object
# View Rating               object
# IMDb Score               float64
# Rotten Tomatoes Score    float64
# Awards Received          float64
# Awards Nominated For     float64
# Boxoffice                 object
# Release Date              object
# Netflix Release Date      object
# Image                     object
# Poster                    object
# dtype: object

# %%
df['Boxoffice']=df['Boxoffice'].fillna("0")

# %%
df['Boxoffice']=df['Boxoffice'].str.replace(",","")

# %%
df['Boxoffice']=df['Boxoffice'].astype(int)
c=df['Boxoffice'].mean()

# %%
for i in range(len(df['Boxoffice'])):
    if df['Boxoffice'][i]==0:
        df['Boxoffice'][i]=c
# Out:
# C:\Users\Gaurav\AppData\Local\Temp\ipykernel_8712\2016987354.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Boxoffice'][i]=c

# %%
df
# Out:
#                                            Title      Genre Languages  \
# 0                               Lets Fight Ghost      Crime   Swedish
# 1                            HOW TO BUILD A GIRL     Comedy   English
# 2                                     Centigrade      Drama   English
# 3                                          ANNE+      Drama   Turkish
# 4                                          Moxie  Animation   English
# ...                                          ...        ...       ...
# 15475                     K-POP Extreme Survival     Comedy   English
# 15476            DreamWorks Shreks Swamp Stories     Comedy   English
# 15477  DreamWorks Happy Holidays from Madagascar  Animation   English
# 15478                DreamWorks Holiday Classics  Animation   English
# 15479   DreamWorks Kung Fu Panda Awesome Secrets  Animation   English
#
#       Series or Movie       Runtime View Rating  IMDb Score  \
# 0              Series  < 30 minutes           R         7.9
# ...

# %%
for i in range(len(df['View Rating'])):
    if df['View Rating'][i]=='Unrated':
        df['View Rating'][i]=df['View Rating'].mode()[0]
# Out:
# C:\Users\Gaurav\AppData\Local\Temp\ipykernel_8712\3023975291.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['View Rating'][i]=df['View Rating'].mode()[0]
# C:\Users\Gaurav\AppData\Local\Temp\ipykernel_8712\3023975291.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['View Rating'][i]=df['View Rating'].mode()[0]
# C:\Users\Gaurav\AppData\Local\Temp\ipykernel_8712\3023975291.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df['Rotten Tomatoes Score']=df['Rotten Tomatoes Score'].fillna(df['Rotten Tomatoes Score'].mean())
df['IMDb Score']=df['IMDb Score'].fillna(df['IMDb Score'].mean())

# %%
df['Rotten Tomatoes Score']=round(df['Rotten Tomatoes Score'],2)
df['IMDb Score']=round(df['IMDb Score'],2)

# %%
df['Awards Received']=df['Awards Received'].astype(int)
df['Awards Nominated For']=df['Awards Nominated For'].astype(int)

# %%
df['Release Date'].str.split
# Out:
# <bound method StringMethods.split of <pandas.core.strings.accessor.StringMethods object at 0x000001242596FFA0>>

# %%
df['Boxoffice']=df['Boxoffice'].astype(int)

# %%
df
# Out:
#                                            Title      Genre Languages  \
# 0                               Lets Fight Ghost      Crime   Swedish
# 1                            HOW TO BUILD A GIRL     Comedy   English
# 2                                     Centigrade      Drama   English
# 3                                          ANNE+      Drama   Turkish
# 4                                          Moxie  Animation   English
# ...                                          ...        ...       ...
# 15475                     K-POP Extreme Survival     Comedy   English
# 15476            DreamWorks Shreks Swamp Stories     Comedy   English
# 15477  DreamWorks Happy Holidays from Madagascar  Animation   English
# 15478                DreamWorks Holiday Classics  Animation   English
# 15479   DreamWorks Kung Fu Panda Awesome Secrets  Animation   English
#
#       Series or Movie       Runtime View Rating  IMDb Score  \
# 0              Series  < 30 minutes           R         7.9
# ...

# %%
a=df['Release Date'].str.split(" ")
for i in range(len(df['Release Date'])):
    df['Release Date'][i]=a[i]
# Out:
# C:\Users\Gaurav\AppData\Local\Temp\ipykernel_14684\3511321924.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Release Date'][i]=a[i]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [60], in <cell line: 2>()
#       1 a=df['Release Date'].str.split(" ")
#       2 for i in range(len(df['Release Date'])):
# ----> 3     df['Release Date'][i]=a[i]
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:1075, in Series.__setitem__(self, key, value)
#    1073 check_deprecated_indexers(key)
#    1074 key = com.apply_if_callable(key, self)
# -> 1075 cacher_needs_updating = self._check_is_chained_assignment_possible()
#    1077 if key is Ellipsis:
# ...

# %%
df.dtypes
# Out:
# Title                     object
# Genre                     object
# Languages                 object
# Series or Movie           object
# Runtime                   object
# View Rating               object
# IMDb Score               float64
# Rotten Tomatoes Score    float64
# Awards Received            int32
# Awards Nominated For       int32
# Boxoffice                  int32
# Release Date              object
# Netflix Release Date      object
# Image                     object
# Poster                    object
# dtype: object

# %%
df
# Out:
#                                            Title      Genre Languages  \
# 0                               Lets Fight Ghost      Crime   Swedish
# 1                            HOW TO BUILD A GIRL     Comedy   English
# 2                                     Centigrade      Drama   English
# 3                                          ANNE+      Drama   Turkish
# 4                                          Moxie  Animation   English
# ...                                          ...        ...       ...
# 15475                     K-POP Extreme Survival     Comedy   English
# 15476            DreamWorks Shreks Swamp Stories     Comedy   English
# 15477  DreamWorks Happy Holidays from Madagascar  Animation   English
# 15478                DreamWorks Holiday Classics  Animation   English
# 15479   DreamWorks Kung Fu Panda Awesome Secrets  Animation   English
#
#       Series or Movie       Runtime View Rating  IMDb Score  \
# 0              Series  < 30 minutes           R         7.9
# ...

# %%
a=df['Netflix Release Date'].str.split("-")

# %%
for i in range(len(df['Netflix Release Date'])):
    df['Netflix Release Date'][i]=a[i][0]
# Out:
# C:\Users\Gaurav\AppData\Local\Temp\ipykernel_8712\1655906145.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Netflix Release Date'][i]=a[i][0]

# %%
df
# Out:
#                                            Title      Genre Languages  \
# 0                               Lets Fight Ghost      Crime   Swedish
# 1                            HOW TO BUILD A GIRL     Comedy   English
# 2                                     Centigrade      Drama   English
# 3                                          ANNE+      Drama   Turkish
# 4                                          Moxie  Animation   English
# ...                                          ...        ...       ...
# 15475                     K-POP Extreme Survival     Comedy   English
# 15476            DreamWorks Shreks Swamp Stories     Comedy   English
# 15477  DreamWorks Happy Holidays from Madagascar  Animation   English
# 15478                DreamWorks Holiday Classics  Animation   English
# 15479   DreamWorks Kung Fu Panda Awesome Secrets  Animation   English
#
#       Series or Movie       Runtime View Rating  IMDb Score  \
# 0              Series  < 30 minutes           R         7.9
# ...

# %%
a=df['Release Date'].str.split(" ")
a
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 15475   NaN
# 15476   NaN
# 15477   NaN
# 15478   NaN
# 15479   NaN
# Name: Release Date, Length: 15480, dtype: float64

# %%
df
# Out:
#                                            Title      Genre Languages  \
# 0                               Lets Fight Ghost      Crime   Swedish
# 1                            HOW TO BUILD A GIRL     Comedy   English
# 2                                     Centigrade      Drama   English
# 3                                          ANNE+      Drama   Turkish
# 4                                          Moxie  Animation   English
# ...                                          ...        ...       ...
# 15475                     K-POP Extreme Survival     Comedy   English
# 15476            DreamWorks Shreks Swamp Stories     Comedy   English
# 15477  DreamWorks Happy Holidays from Madagascar  Animation   English
# 15478                DreamWorks Holiday Classics  Animation   English
# 15479   DreamWorks Kung Fu Panda Awesome Secrets  Animation   English
#
#       Series or Movie       Runtime View Rating  IMDb Score  \
# 0              Series  < 30 minutes           R         7.9
# ...

# %%
df['Release Date']=df['Release Date'][0][0]

# %%
df
# Out:
#                                            Title      Genre Languages  \
# 0                               Lets Fight Ghost      Crime   Swedish
# 1                            HOW TO BUILD A GIRL     Comedy   English
# 2                                     Centigrade      Drama   English
# 3                                          ANNE+      Drama   Turkish
# 4                                          Moxie  Animation   English
# ...                                          ...        ...       ...
# 15475                     K-POP Extreme Survival     Comedy   English
# 15476            DreamWorks Shreks Swamp Stories     Comedy   English
# 15477  DreamWorks Happy Holidays from Madagascar  Animation   English
# 15478                DreamWorks Holiday Classics  Animation   English
# 15479   DreamWorks Kung Fu Panda Awesome Secrets  Animation   English
#
#       Series or Movie       Runtime View Rating  IMDb Score  \
# 0              Series  < 30 minutes           R         7.9
# ...

# %%
df.isnull().sum()
# Out:
# Title                       0
# Genre                       0
# Languages                   0
# Series or Movie             0
# Runtime                     0
# View Rating                 0
# IMDb Score                  0
# Rotten Tomatoes Score       0
# Awards Received             0
# Awards Nominated For        0
# Boxoffice                   0
# Release Date                0
# Netflix Release Date        0
# Image                       0
# Poster                   3638
# dtype: int64

# %%
df['Release Date']=df1['Release Date']

# %%
df
# Out:
#                                            Title      Genre Languages  \
# 0                               Lets Fight Ghost      Crime   Swedish
# 1                            HOW TO BUILD A GIRL     Comedy   English
# 2                                     Centigrade      Drama   English
# 3                                          ANNE+      Drama   Turkish
# 4                                          Moxie  Animation   English
# ...                                          ...        ...       ...
# 15475                     K-POP Extreme Survival     Comedy   English
# 15476            DreamWorks Shreks Swamp Stories     Comedy   English
# 15477  DreamWorks Happy Holidays from Madagascar  Animation   English
# 15478                DreamWorks Holiday Classics  Animation   English
# 15479   DreamWorks Kung Fu Panda Awesome Secrets  Animation   English
#
#       Series or Movie       Runtime View Rating  IMDb Score  \
# 0              Series  < 30 minutes           R         7.9
# ...

# %%
df['Release Date']
# Out:
# 0        12 Dec 2008
# 1        08 May 2020
# 2        28 Aug 2020
# 3        01 Oct 2016
# 4        22 Sep 2011
#             ...
# 15475            NaN
# 15476            NaN
# 15477            NaN
# 15478            NaN
# 15479            NaN
# Name: Release Date, Length: 15480, dtype: object

# %%
df['Release Date']=df['Release Date'].fillna('a b c')

# %%
df
# Out:
#                                            Title      Genre Languages  \
# 0                               Lets Fight Ghost      Crime   Swedish
# 1                            HOW TO BUILD A GIRL     Comedy   English
# 2                                     Centigrade      Drama   English
# 3                                          ANNE+      Drama   Turkish
# 4                                          Moxie  Animation   English
# ...                                          ...        ...       ...
# 15475                     K-POP Extreme Survival     Comedy   English
# 15476            DreamWorks Shreks Swamp Stories     Comedy   English
# 15477  DreamWorks Happy Holidays from Madagascar  Animation   English
# 15478                DreamWorks Holiday Classics  Animation   English
# 15479   DreamWorks Kung Fu Panda Awesome Secrets  Animation   English
#
#       Series or Movie       Runtime View Rating  IMDb Score  \
# 0              Series  < 30 minutes           R         7.9
# ...

# %%
a=df['Release Date'].str.split(" ")
a
# Out:
# 0        [12, Dec, 2008]
# 1        [08, May, 2020]
# 2        [28, Aug, 2020]
# 3        [01, Oct, 2016]
# 4        [22, Sep, 2011]
#               ...
# 15475          [a, b, c]
# 15476          [a, b, c]
# 15477          [a, b, c]
# 15478          [a, b, c]
# 15479          [a, b, c]
# Name: Release Date, Length: 15480, dtype: object

# %%
for i in range(len(df['Release Date'])):
    df['Release Date'][i]=a[i][2]
# Out:
# C:\Users\Gaurav\AppData\Local\Temp\ipykernel_8712\591356348.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Release Date'][i]=a[i][2]

# %%
for i in range(len(df['Release Date'])):
    if df['Release Date'][i]=='c':
        df['Release Date'][i]=df['Netflix Release Date'][i]
# Out:
# C:\Users\Gaurav\AppData\Local\Temp\ipykernel_8712\1793591346.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Release Date'][i]=df['Netflix Release Date'][i]

# %%
df
# Out:
#                                            Title      Genre Languages  \
# 0                               Lets Fight Ghost      Crime   Swedish
# 1                            HOW TO BUILD A GIRL     Comedy   English
# 2                                     Centigrade      Drama   English
# 3                                          ANNE+      Drama   Turkish
# 4                                          Moxie  Animation   English
# ...                                          ...        ...       ...
# 15475                     K-POP Extreme Survival     Comedy   English
# 15476            DreamWorks Shreks Swamp Stories     Comedy   English
# 15477  DreamWorks Happy Holidays from Madagascar  Animation   English
# 15478                DreamWorks Holiday Classics  Animation   English
# 15479   DreamWorks Kung Fu Panda Awesome Secrets  Animation   English
#
#       Series or Movie       Runtime View Rating  IMDb Score  \
# 0              Series  < 30 minutes           R         7.9
# ...

# %%
df.isnull().sum()
# Out:
# Title                       0
# Genre                       0
# Languages                   0
# Series or Movie             0
# Runtime                     0
# View Rating                 0
# IMDb Score                  0
# Rotten Tomatoes Score       0
# Awards Received             0
# Awards Nominated For        0
# Boxoffice                   0
# Release Date                0
# Netflix Release Date        0
# Image                       0
# Poster                   3638
# dtype: int64

# %%
df.dtypes
# Out:
# Title                     object
# Genre                     object
# Languages                 object
# Series or Movie           object
# Runtime                   object
# View Rating               object
# IMDb Score               float64
# Rotten Tomatoes Score    float64
# Awards Received            int32
# Awards Nominated For       int32
# Boxoffice                  int32
# Release Date              object
# Netflix Release Date      object
# Image                     object
# Poster                    object
# dtype: object

# %%
df
# Out:
#                                            Title      Genre Languages  \
# 0                               Lets Fight Ghost      Crime   Swedish
# 1                            HOW TO BUILD A GIRL     Comedy   English
# 2                                     Centigrade      Drama   English
# 3                                          ANNE+      Drama   Turkish
# 4                                          Moxie  Animation   English
# ...                                          ...        ...       ...
# 15475                     K-POP Extreme Survival     Comedy   English
# 15476            DreamWorks Shreks Swamp Stories     Comedy   English
# 15477  DreamWorks Happy Holidays from Madagascar  Animation   English
# 15478                DreamWorks Holiday Classics  Animation   English
# 15479   DreamWorks Kung Fu Panda Awesome Secrets  Animation   English
#
#       Series or Movie       Runtime View Rating  IMDb Score  \
# 0              Series  < 30 minutes           R         7.9
# ...

# %%
df2=df

# %%
df2
# Out:
#                                            Title      Genre Languages  \
# 0                               Lets Fight Ghost      Crime   Swedish
# 1                            HOW TO BUILD A GIRL     Comedy   English
# 2                                     Centigrade      Drama   English
# 3                                          ANNE+      Drama   Turkish
# 4                                          Moxie  Animation   English
# ...                                          ...        ...       ...
# 15475                     K-POP Extreme Survival     Comedy   English
# 15476            DreamWorks Shreks Swamp Stories     Comedy   English
# 15477  DreamWorks Happy Holidays from Madagascar  Animation   English
# 15478                DreamWorks Holiday Classics  Animation   English
# 15479   DreamWorks Kung Fu Panda Awesome Secrets  Animation   English
#
#       Series or Movie       Runtime View Rating  IMDb Score  \
# 0              Series  < 30 minutes           R         7.9
# ...

# %%
df2.to_excel("C:/Users/Gaurav/Desktop/Projects/OTT/output.xlsx")
